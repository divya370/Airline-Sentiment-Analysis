# %% [markdown]
# ## Airline Review Sentiment Analysis

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
from scipy.special import softmax
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cleaned_data.csv')
df.head()
# Out:
#    rating         country        date  \
# 0     3.0           Italy  04-01-2024
# 1     1.0           Spain  03-28-2024
# 2     5.0  United Kingdom  03-18-2024
# 3     1.0          Canada  03-16-2024
# 4     7.0  United Kingdom  03-10-2024
#
#                                               review Type Of Traveller  \
# 0    Very cheeky check-in system: this did not ha...    Couple Leisure
# 1    Terrible customer service. Handling in Marra...    Family Leisure
# 2    Luton to Faro and return Faro to Luton 10 da...    Couple Leisure
# 3    Very bad airline. I spent 100 pounds check i...    Family Leisure
# 4    When things go wrong with low-cost carriers,...      Solo Leisure
#
#        Seat Type                  Route  Date Flown  Seat Comfort  \
# 0  Economy Class    Manchester to Milan  March 2024           1.0
# 1  Economy Class   Marrakech to Sevilla  March 2024           2.0
# 2  Economy Class          Luton to Faro  March 2024           1.0
# 3  Economy Class  Edinburgh to Stansted  March 2024           1.0
# 4  Economy Class      Stansted to Sofia  March 2024           3.0
#
#    Cabin Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                  2.0               2.0                     1.0
# 1                  4.0               2.0                     1.0
# 2                  3.0               2.0                     3.0
# 3                  1.0               2.0                     3.0
# 4                  4.0               2.0                     3.0
#
#    Ground Service  Value For Money Recommended Airlines  \
# 0             2.0              2.0          no  ryanair
# 1             1.0              3.0          no  ryanair
# 2             1.0              2.0          no  ryanair
# 3             1.0              2.0          no  ryanair
# 4             3.0              5.0         yes  ryanair
#
#                              author  Verified  review_length
# 0                            Y Chen         0            108
# 1                       Diego Perez         0            594
# 2  15 reviews\n\n\n\nRichard Hodges         1            211
# 3                             G Han         1             84
# 4                           R Vines         1            111

# %% [markdown]
# ### Sentiment Analysis Using RoBERTa

# %%
model_path = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_path)
config = AutoConfig.from_pretrained(model_path)
roberta_model = AutoModelForSequenceClassification.from_pretrained(model_path)

# a function that takes text and model to calculate probability of each sentiment
def sentiment_analyzer(text, model):
    encoded_input = tokenizer(text, padding=True, truncation=True, return_tensors="pt", max_length=512)
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = np.round(softmax(scores), 2)
    scores_dict = {"neg": scores[0], "neu": scores[1], "pos": scores[2]}
    return scores_dict

# %%
df["probabilities"] = df["review"].apply(sentiment_analyzer, model=roberta_model)

# %%
# Apply the RoBERTa function
probabilities = df["probabilities"].apply(pd.Series)
df = df.join(probabilities)
df = df.drop("probabilities", axis=1)

# Calculate the polarity for each text
polarity_weights = torch.tensor([-1, 0, 1])
probs = torch.tensor(df[["neg", "neu", "pos"]].values)
polarity = polarity_weights * probs
polarity = polarity.sum(dim=-1)
polarity_scaled = nn.Tanh()(polarity)

# Assign labels for each text based on polarity
df["roberta_polarity"] = polarity_scaled.numpy()
df["roberta_sentiment"] = pd.cut(df["roberta_polarity"],
                                  bins=[-1.0, -0.25, 0.25, 1.0],
                                  labels=["Negative", "Neutral", "Positive"])
df = df.drop(["neu", "neg", "pos"], axis=1)

# %%
df.roberta_sentiment.value_counts()
# Out:
# Negative    8296
# Positive    3215
# Neutral      665
# Name: roberta_sentiment, dtype: int64

# %% [markdown]
#  Saving the Progress

# %%
df.to_csv('Sentiment.csv', index=False)

# %% [markdown]
# ## Geocoding API (NOMINATIM): Obtaining Central Latitude and Longitude of Passenger's Country of Origin

# %%
df1 = pd.read_csv('Sentiment.csv')
df1.head()
# Out:
#    rating         country        date  \
# 0     3.0           Italy  04-01-2024
# 1     1.0           Spain  03-28-2024
# 2     5.0  United Kingdom  03-18-2024
# 3     1.0          Canada  03-16-2024
# 4     7.0  United Kingdom  03-10-2024
#
#                                               review Type Of Traveller  \
# 0    Very cheeky check-in system: this did not ha...    Couple Leisure
# 1    Terrible customer service. Handling in Marra...    Family Leisure
# 2    Luton to Faro and return Faro to Luton 10 da...    Couple Leisure
# 3    Very bad airline. I spent 100 pounds check i...    Family Leisure
# 4    When things go wrong with low-cost carriers,...      Solo Leisure
#
#        Seat Type                  Route  Date Flown  Seat Comfort  \
# 0  Economy Class    Manchester to Milan  March 2024           1.0
# 1  Economy Class   Marrakech to Sevilla  March 2024           2.0
# 2  Economy Class          Luton to Faro  March 2024           1.0
# 3  Economy Class  Edinburgh to Stansted  March 2024           1.0
# 4  Economy Class      Stansted to Sofia  March 2024           3.0
#
#    Cabin Staff Service  ...  Inflight Entertainment  Ground Service  \
# 0                  2.0  ...                     1.0             2.0
# 1                  4.0  ...                     1.0             1.0
# 2                  3.0  ...                     3.0             1.0
# 3                  1.0  ...                     3.0             1.0
# 4                  4.0  ...                     3.0             3.0
#
#    Value For Money  Recommended Airlines                            author  \
# 0              2.0           no  ryanair                            Y Chen
# 1              3.0           no  ryanair                       Diego Perez
# 2              2.0           no  ryanair  15 reviews\n\n\n\nRichard Hodges
# 3              2.0           no  ryanair                             G Han
# 4              5.0          yes  ryanair                           R Vines
#
#   Verified  review_length  roberta_polarity  roberta_sentiment
# 0        0            108         -0.721132           Negative
# 1        0            594         -0.652707           Negative
# 2        1            211         -0.371360           Negative
# 3        1             84         -0.735222           Negative
# 4        1            111         -0.089758            Neutral
#
# [5 rows x 21 columns]

# %%
# !pip install pycountry
# Out:
# Requirement already satisfied: pycountry in /Users/krish/anaconda3/lib/python3.11/site-packages (23.12.11)

# %% [markdown]
# ### Generating country code based on country name

# %%
import pycountry 
def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_2
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE

df1['CODE']=alpha3code(df1.country)
df1.head()
# Out:
#    rating         country        date  \
# 0     3.0           Italy  04-01-2024
# 1     1.0           Spain  03-28-2024
# 2     5.0  United Kingdom  03-18-2024
# 3     1.0          Canada  03-16-2024
# 4     7.0  United Kingdom  03-10-2024
#
#                                               review Type Of Traveller  \
# 0    Very cheeky check-in system: this did not ha...    Couple Leisure
# 1    Terrible customer service. Handling in Marra...    Family Leisure
# 2    Luton to Faro and return Faro to Luton 10 da...    Couple Leisure
# 3    Very bad airline. I spent 100 pounds check i...    Family Leisure
# 4    When things go wrong with low-cost carriers,...      Solo Leisure
#
#        Seat Type                  Route  Date Flown  Seat Comfort  \
# 0  Economy Class    Manchester to Milan  March 2024           1.0
# 1  Economy Class   Marrakech to Sevilla  March 2024           2.0
# 2  Economy Class          Luton to Faro  March 2024           1.0
# 3  Economy Class  Edinburgh to Stansted  March 2024           1.0
# 4  Economy Class      Stansted to Sofia  March 2024           3.0
#
#    Cabin Staff Service  ...  Ground Service  Value For Money  Recommended  \
# 0                  2.0  ...             2.0              2.0           no
# 1                  4.0  ...             1.0              3.0           no
# 2                  3.0  ...             1.0              2.0           no
# 3                  1.0  ...             1.0              2.0           no
# 4                  4.0  ...             3.0              5.0          yes
#
#    Airlines                            author Verified review_length  \
# 0   ryanair                            Y Chen        0           108
# 1   ryanair                       Diego Perez        0           594
# 2   ryanair  15 reviews\n\n\n\nRichard Hodges        1           211
# 3   ryanair                             G Han        1            84
# 4   ryanair                           R Vines        1           111
#
#    roberta_polarity  roberta_sentiment  CODE
# 0         -0.721132           Negative    IT
# 1         -0.652707           Negative    ES
# 2         -0.371360           Negative    GB
# 3         -0.735222           Negative    CA
# 4         -0.089758            Neutral    GB
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Using Nominatim to get location

# %%
from geopy.geocoders import Nominatim

# Initialize geocoder
geolocator = Nominatim(user_agent="Data-2")

# Get unique country codes
codes = df1['CODE'].unique()

# Function to geocode a single country code
def geocode_country_code(code):
    location = geolocator.geocode(code)
    if location:
        return pd.Series({'CODE': code, 'Latitude': location.latitude, 'Longitude': location.longitude})
    else:
        return pd.Series({'CODE': code, 'Latitude': None, 'Longitude': None})

# Create DataFrame with latitude and longitude pairs for each country code
geocoded_data = pd.DataFrame([geocode_country_code(code) for code in codes])
geocoded_data.head()
# Out:
#   CODE   Latitude   Longitude
# 0   IT  42.638426   12.674297
# 1   ES  39.326068   -4.837979
# 2   GB  54.702354   -3.276575
# 3   CA  61.066692 -107.991707
# 4   PL  52.215933   19.134422

# %%
# Merge geocoded data with original DataFrame
merged_df = pd.merge(df1, geocoded_data, on='CODE', how='left')

# %%
merged_df.to_csv('Final_csv.csv')

# %%
merged_df.shape
# Out:
# (12176, 24)

# %%
df = pd.read_csv('Final_csv.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  rating         country        date  \
# 0           0     3.0           Italy  04-01-2024
# 1           1     1.0           Spain  03-28-2024
# 2           2     5.0  United Kingdom  03-18-2024
# 3           3     1.0          Canada  03-16-2024
# 4           4     7.0  United Kingdom  03-10-2024
#
#                                               review Type Of Traveller  \
# 0    Very cheeky check-in system: this did not ha...    Couple Leisure
# 1    Terrible customer service. Handling in Marra...    Family Leisure
# 2    Luton to Faro and return Faro to Luton 10 da...    Couple Leisure
# 3    Very bad airline. I spent 100 pounds check i...    Family Leisure
# 4    When things go wrong with low-cost carriers,...      Solo Leisure
#
#        Seat Type                  Route  Date Flown  Seat Comfort  ...  \
# 0  Economy Class    Manchester to Milan  March 2024           1.0  ...
# 1  Economy Class   Marrakech to Sevilla  March 2024           2.0  ...
# 2  Economy Class          Luton to Faro  March 2024           1.0  ...
# 3  Economy Class  Edinburgh to Stansted  March 2024           1.0  ...
# 4  Economy Class      Stansted to Sofia  March 2024           3.0  ...
#
#    Recommended  Airlines                            author  Verified  \
# 0           no   ryanair                            Y Chen         0
# 1           no   ryanair                       Diego Perez         0
# 2           no   ryanair  15 reviews\n\n\n\nRichard Hodges         1
# 3           no   ryanair                             G Han         1
# 4          yes   ryanair                           R Vines         1
#
#    review_length roberta_polarity roberta_sentiment CODE   Latitude  \
# 0            108        -0.721132          Negative   IT  42.638426
# 1            594        -0.652707          Negative   ES  39.326068
# 2            211        -0.371360          Negative   GB  54.702354
# 3             84        -0.735222          Negative   CA  61.066692
# 4            111        -0.089758           Neutral   GB  54.702354
#
#     Longitude
# 0   12.674297
# 1   -4.837979
# 2   -3.276575
# 3 -107.991707
# 4   -3.276575
#
# [5 rows x 25 columns]

# %%
# sentiment , recommended encode
